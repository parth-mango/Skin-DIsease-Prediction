# %% [markdown]
# <a href="https://colab.research.google.com/github/parth-mango/Skin-DIsease-Prediction/blob/main/skidisprev1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Skin Disease Prediction Project**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
from torchvision import transforms
import torch.nn as nn
import torch.utils.data as data
import torchvision
import torch.nn.functional as F
import torch.optim as optim
import torchvision.models as models
import os

# %%
# ! git clone https://github.com/parth-mango/Skin-DIsease-Prediction.git

# %%
"""Here we download data and embeddings"""
# !wget https://transfer.sh/1wtxuB6/test_emb.zip
# !wget https://transfer.sh/16dReG7/train_emb.zip
# !wget https://transfer.sh/1KTFWhD/test.zip
# !wget https://transfer.sh/1rvrgNR/train.zip

# %%
# !unzip test_emb.zip -d /content/images/
# !unzip train_emb.zip -d /content/images/
# !unzip train.zip -d /content/images/
# !unzip test.zip -d //content/images/

# %%
# %cd /content/Skin-DIsease-Prediction

# %%
"""make outputs and new models folder in main repo"""
# !mkdir new_models
# !mkdir outputs

# %%
# !python train.py '/content/Skin-DIsease-Prediction/outputs'
# Out:
# Streaming output truncated to the last 5000 lines.
# Train Epoch: 6 [11840/15557 (76%)]	Loss: 2.075751	Acc: 0.376600
# Train Epoch: 6 [12160/15557 (78%)]	Loss: 2.076071	Acc: 0.376148
# Train Epoch: 6 [12480/15557 (80%)]	Loss: 2.075043	Acc: 0.376918
# Train Epoch: 6 [12800/15557 (82%)]	Loss: 2.076213	Acc: 0.376559
# Train Epoch: 6 [13120/15557 (84%)]	Loss: 2.075410	Acc: 0.376521
# Train Epoch: 6 [13440/15557 (86%)]	Loss: 2.074529	Acc: 0.376781
# Train Epoch: 6 [13760/15557 (88%)]	Loss: 2.070484	Acc: 0.377900
# Train Epoch: 6 [14080/15557 (91%)]	Loss: 2.069872	Acc: 0.378189
# Train Epoch: 6 [14400/15557 (93%)]	Loss: 2.068570	Acc: 0.378950
# Train Epoch: 6 [14720/15557 (95%)]	Loss: 2.069070	Acc: 0.378932
# Train Epoch: 6 [15040/15557 (97%)]	Loss: 2.067312	Acc: 0.379843
# Train Epoch: 6 [15360/15557 (99%)]	Loss: 2.066729	Acc: 0.380133
#
# Test Epoch: 6	Loss: 2.097344	Acc: 0.382059
#
#  lr: 0.0001
# Train Epoch: 7 [0/15557 (0%)]	Loss: 2.176728	Acc: 0.375000
# ...
